# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `YOUR IMPORT TEXT HERE`

# %%
# Import dependencies
import pandas
from pymongo import MongoClient

# %%
# MongoClient
mongo = MongoClient(port=27017)

# %%
# database creation
print(mongo.list_database_names())
# Out:
# ['admin', 'autosaurus', 'classDB', 'config', 'fruits_db', 'local', 'test', 'uk_food']

# %%
# uk_food database to a variable name
uk_food_db = mongo['uk_food']

# %%
# collections in our new database
uk_food_db.list_collection_names()
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
print(uk_food_db.establishments.find_one())
# Out:
# {'_id': ObjectId('643057f8130a14a279426615'), 'FHRSID': 254719, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000069980', 'BusinessName': 'Refreshment Kiosk', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': 'The Bay', 'AddressLine2': 'St Margarets Bay', 'AddressLine3': 'Kent', 'AddressLine4': '', 'PostCode': 'CT15 6DY', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2022-03-24T00:00:00', 'LocalAuthorityCode': '182', 'LocalAuthorityName': 'Dover', 'LocalAuthorityWebSite': 'http://www.dover.gov.uk/', 'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': '1.387974', 'latitude': '51.152225'}, 'RightToReply': '', 'Distance': 4587.347174863443, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'https://api.ratings.food.gov.uk/establishments/254719'}]}

# %%
# assign the collection to a variable
establishments = uk_food_db['establishments']
establishments
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'uk_food'), 'establishments')

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# dictionary for the new restaurant data
new_restaurant = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# new restaurant into the collection
establishments.insert_one(new_restaurant)

# %%
# new restaurant was inserted
query = {'BusinessName': 'Penang Flavours'}
results = establishments.find(query)
for result in results:
    print(result)
# Out:
# {'_id': ObjectId('643058399420424c529ed646'), 'BusinessName': 'Penang Flavours', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': '', 'AddressLine1': 'Penang Flavours', 'AddressLine2': '146A Plumstead Rd', 'AddressLine3': 'London', 'AddressLine4': '', 'PostCode': 'SE18 7DY', 'Phone': '', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''}, 'SchemeType': 'FHRS', 'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'}, 'RightToReply': '', 'Distance': 4623.972328074718, 'NewRatingPending': True}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
fields = {'BusinessTypeID': 1, 'BusinessType': 'Restaurant/Cafe/Canteen'}

# Capture the results to a variable
results = establishments.find(query, fields)

# Pretty print the results
for result in results:
    print(result)
# Out:
# {'_id': ObjectId('643058399420424c529ed646'), 'BusinessTypeID': '', 'BusinessType': 'Restaurant/Cafe/Canteen'}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
uk_food_db.establishments.update_one(
    {'BusinessName': 'Penang Flavours'},
    {'$set':
        {'BusinessTypeID': 1}
     }
)

# %%
# Confirm that the new restaurant was updated
query = {'BusinessName': 'Penang Flavours'}
results = establishments.find(query)
for result in results:
    print(result)
# Out:
# {'_id': ObjectId('643058399420424c529ed646'), 'BusinessName': 'Penang Flavours', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': 'Penang Flavours', 'AddressLine2': '146A Plumstead Rd', 'AddressLine3': 'London', 'AddressLine4': '', 'PostCode': 'SE18 7DY', 'Phone': '', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''}, 'SchemeType': 'FHRS', 'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'}, 'RightToReply': '', 'Distance': 4623.972328074718, 'NewRatingPending': True}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"

query = {'LocalAuthorityName': 'Dover'}
dover_local = establishments.count_documents(query)
dover_local
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many(query)

# %%
# Check if any remaining documents include Dover
results = establishments.find(query)
for result in results:
    print(result)

# %%
# Check that other documents remain with 'find_one'
establishments.find_one()
# Out:
# {'_id': ObjectId('643057f8130a14a2794268fc'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.195625', 'latitude': '51.083812'},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers. Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude
establishments.update_many({}, [ {'$set':{ "geocode.longitude" : {'$toDecimal': "$geocode.longitude"}
                                         }
                                 } ]
                          )

# %%
# Change the data type from String to Decimal for latitude
establishments.update_many({}, [ {'$set':{ "geocode.latitude" : {'$toDecimal': "$geocode.latitude"}}} ])

# %%
# Check that the coordinates are now numbers
query = {}
fields = {'geocode'}

# Capture the results to a variable
results = establishments.find(query, fields)

# Pretty print the results
for result in results:
    print(result)
# Out:
# {'_id': ObjectId('643057f8130a14a2794268fc'), 'geocode': {'longitude': Decimal128('1.195625'), 'latitude': Decimal128('51.083812')}}
# {'_id': ObjectId('643057f8130a14a2794268fd'), 'geocode': {'longitude': Decimal128('1.196408'), 'latitude': Decimal128('51.086058')}}
# {'_id': ObjectId('643057f8130a14a2794268fe'), 'geocode': {'longitude': Decimal128('1.194762'), 'latitude': Decimal128('51.085797')}}
# {'_id': ObjectId('643057f8130a14a279426901'), 'geocode': {'longitude': Decimal128('1.188537'), 'latitude': Decimal128('51.08084')}}
# {'_id': ObjectId('643057f8130a14a279426902'), 'geocode': {'longitude': Decimal128('1.188537'), 'latitude': Decimal128('51.08084')}}
# {'_id': ObjectId('643057f8130a14a279426903'), 'geocode': {'longitude': Decimal128('1.188537'), 'latitude': Decimal128('51.08084')}}
# {'_id': ObjectId('643057f8130a14a279426904'), 'geocode': {'longitude': Decimal128('1.188537'), 'latitude': Decimal128('51.08084')}}
# {'_id': ObjectId('643057f8130a14a279426905'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a279426906'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a279426907'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a279426908'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a279426909'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a27942690a'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a27942690b'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a27942690c'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a27942690d'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a27942690e'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a27942690f'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a279426910'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a279426911'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a279426912'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a279426913'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a279426914'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a279426915'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a279426916'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a279426917'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a279426918'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a279426919'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a27942691a'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a27942691b'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a27942691c'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a27942691d'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a27942691e'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a27942691f'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a279426920'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a279426921'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a279426922'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a279426923'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a279426924'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a279426925'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a279426926'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a279426927'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a279426928'), 'geocode': {'longitude': Decimal128('1.18590330311705'), 'latitude': Decimal128('51.0783519967076')}}
# {'_id': ObjectId('643057f8130a14a279426929'), 'geocode': {'longitude': Decimal128('1.18794649942731'), 'latitude': Decimal128('51.0805695006979')}}
# {'_id': ObjectId('643057f8130a14a27942692b'), 'geocode': {'longitude': Decimal128('1.18516'), 'latitude': Decimal128('51.078449')}}
# {'_id': ObjectId('643057f8130a14a27942692c'), 'geocode': {'longitude': Decimal128('1.202055'), 'latitude': Decimal128('51.095015')}}
# {'_id': ObjectId('643057f8130a14a27942692d'), 'geocode': {'longitude': Decimal128('1.187083'), 'latitude': Decimal128('51.080673')}}
# {'_id': ObjectId('643057f8130a14a27942692e'), 'geocode': {'longitude': Decimal128('1.186825'), 'latitude': Decimal128('51.080446')}}
# {'_id': ObjectId('643057f8130a14a27942692f'), 'geocode': {'longitude': Decimal128('1.18628335007084'), 'latitude': Decimal128('51.079985650005')}}
# {'_id': ObjectId('643057f8130a14a279426930'), 'geocode': {'longitude': Decimal128('1.186485'), 'latitude': Decimal128('51.080284')}}
# {'_id': ObjectId('643057f8130a14a279426931'), 'geocode': {'longitude': Decimal128('1.186485'), 'latitude': Decimal128('51.080284')}}
# {'_id': ObjectId('643057f8130a14a279426934'), 'geocode': {'longitude': Decimal128('1.194306'), 'latitude': Decimal128('51.087887')}}
# {'_id': ObjectId('643057f8130a14a279426935'), 'geocode': {'longitude': Decimal128('1.186067'), 'latitude': Decimal128('51.080224')}}
# {'_id': ObjectId('643057f8130a14a279426936'), 'geocode': {'longitude': Decimal128('1.185368'), 'latitude': Decimal128('51.079613')}}
# {'_id': ObjectId('643057f8130a14a279426937'), 'geocode': {'longitude': Decimal128('1.185368'), 'latitude': Decimal128('51.079613')}}
# {'_id': ObjectId('643057f8130a14a279426938'), 'geocode': {'longitude': Decimal128('1.183585'), 'latitude': Decimal128('51.077971')}}
# {'_id': ObjectId('643057f8130a14a279426939'), 'geocode': {'longitude': Decimal128('1.188902'), 'latitude': Decimal128('51.083232')}}
# {'_id': ObjectId('643057f8130a14a27942693b'), 'geocode': {'longitude': Decimal128('1.186309'), 'latitude': Decimal128('51.080838')}}
# {'_id': ObjectId('643057f8130a14a27942693c'), 'geocode': {'longitude': Decimal128('1.187056'), 'latitude': Decimal128('51.081735')}}
# {'_id': ObjectId('643057f8130a14a27942693d'), 'geocode': {'longitude': Decimal128('1.186715'), 'latitude': Decimal128('51.081546')}}
# {'_id': ObjectId('643057f8130a14a27942693e'), 'geocode': {'longitude': Decimal128('1.184194'), 'latitude': Decimal128('51.07915')}}
# {'_id': ObjectId('643057f8130a14a27942693f'), 'geocode': {'longitude': Decimal128('1.184194'), 'latitude': Decimal128('51.07915')}}
# {'_id': ObjectId('643057f8130a14a279426941'), 'geocode': {'longitude': Decimal128('1.184916'), 'latitude': Decimal128('51.0803')}}
# {'_id': ObjectId('643057f8130a14a279426942'), 'geocode': {'longitude': Decimal128('1.190896'), 'latitude': Decimal128('51.086262')}}
# {'_id': ObjectId('643057f8130a14a279426945'), 'geocode': {'longitude': Decimal128('1.18601894378662'), 'latitude': Decimal128('51.0818061828613')}}
# {'_id': ObjectId('643057f8130a14a279426946'), 'geocode': {'longitude': Decimal128('1.1920251'), 'latitude': Decimal128('51.0877821')}}
# {'_id': ObjectId('643057f8130a14a279426948'), 'geocode': {'longitude': Decimal128('1.18425798416138'), 'latitude': Decimal128('51.0804748535156')}}
# {'_id': ObjectId('643057f8130a14a279426949'), 'geocode': {'longitude': Decimal128('1.18421399593353'), 'latitude': Decimal128('51.0804824829102')}}
# {'_id': ObjectId('643057f8130a14a27942694a'), 'geocode': {'longitude': Decimal128('1.18421399593353'), 'latitude': Decimal128('51.0804824829102')}}
# {'_id': ObjectId('643057f8130a14a27942694b'), 'geocode': {'longitude': Decimal128('1.182962'), 'latitude': Decimal128('51.0793')}}
# {'_id': ObjectId('643057f8130a14a27942694c'), 'geocode': {'longitude': Decimal128('1.182962'), 'latitude': Decimal128('51.079301')}}
# {'_id': ObjectId('643057f8130a14a27942694d'), 'geocode': {'longitude': Decimal128('1.18431901931763'), 'latitude': Decimal128('51.0809478759766')}}
# {'_id': ObjectId('643057f8130a14a27942694e'), 'geocode': {'longitude': Decimal128('1.18429'), 'latitude': Decimal128('51.080956')}}
# {'_id': ObjectId('643057f8130a14a27942694f'), 'geocode': {'longitude': Decimal128('1.18429'), 'latitude': Decimal128('51.080956')}}
# {'_id': ObjectId('643057f8130a14a279426950'), 'geocode': {'longitude': Decimal128('1.18429'), 'latitude': Decimal128('51.080956')}}
# {'_id': ObjectId('643057f8130a14a279426951'), 'geocode': {'longitude': Decimal128('1.18429'), 'latitude': Decimal128('51.080956')}}
# {'_id': ObjectId('643057f8130a14a279426952'), 'geocode': {'longitude': Decimal128('1.19522100055125'), 'latitude': Decimal128('51.0917365039471')}}
# {'_id': ObjectId('643057f8130a14a279426953'), 'geocode': {'longitude': Decimal128('1.201433'), 'latitude': Decimal128('51.097794')}}
# {'_id': ObjectId('643057f8130a14a279426954'), 'geocode': {'longitude': Decimal128('1.183893'), 'latitude': Decimal128('51.080804')}}
# {'_id': ObjectId('643057f8130a14a279426955'), 'geocode': {'longitude': Decimal128('1.183894'), 'latitude': Decimal128('51.080805')}}
# {'_id': ObjectId('643057f8130a14a279426956'), 'geocode': {'longitude': Decimal128('1.182875'), 'latitude': Decimal128('51.079905')}}
# {'_id': ObjectId('643057f8130a14a279426957'), 'geocode': {'longitude': Decimal128('1.1835476'), 'latitude': Decimal128('51.0810258')}}
# {'_id': ObjectId('643057f8130a14a279426958'), 'geocode': {'longitude': Decimal128('1.182805'), 'latitude': Decimal128('51.080339')}}
# {'_id': ObjectId('643057f8130a14a279426959'), 'geocode': {'longitude': Decimal128('1.182805'), 'latitude': Decimal128('51.080339')}}
# {'_id': ObjectId('643057f8130a14a27942695a'), 'geocode': {'longitude': Decimal128('1.182805'), 'latitude': Decimal128('51.08034')}}
# {'_id': ObjectId('643057f8130a14a27942695b'), 'geocode': {'longitude': Decimal128('1.182805'), 'latitude': Decimal128('51.08034')}}
# {'_id': ObjectId('643057f8130a14a27942695c'), 'geocode': {'longitude': Decimal128('1.182805'), 'latitude': Decimal128('51.08034')}}
# {'_id': ObjectId('643057f8130a14a27942695d'), 'geocode': {'longitude': Decimal128('1.182805'), 'latitude': Decimal128('51.08034')}}
# {'_id': ObjectId('643057f8130a14a27942695f'), 'geocode': {'longitude': Decimal128('1.1823865'), 'latitude': Decimal128('51.0802956')}}
# {'_id': ObjectId('643057f8130a14a279426960'), 'geocode': {'longitude': Decimal128('1.181832'), 'latitude': Decimal128('51.079889')}}
# {'_id': ObjectId('643057f8130a14a279426961'), 'geocode': {'longitude': Decimal128('1.1813759803772'), 'latitude': Decimal128('51.079532623291')}}
# {'_id': ObjectId('643057f8130a14a279426962'), 'geocode': {'longitude': Decimal128('1.1822069'), 'latitude': Decimal128('51.0803409')}}
# {'_id': ObjectId('643057f8130a14a279426963'), 'geocode': {'longitude': Decimal128('1.181365'), 'latitude': Decimal128('51.079542')}}
# {'_id': ObjectId('643057f8130a14a279426964'), 'geocode': {'longitude': Decimal128('1.181365'), 'latitude': Decimal128('51.079542')}}
# {'_id': ObjectId('643057f8130a14a279426965'), 'geocode': {'longitude': Decimal128('1.181365'), 'latitude': Decimal128('51.079542')}}
# {'_id': ObjectId('643057f8130a14a279426966'), 'geocode': {'longitude': Decimal128('1.1817077'), 'latitude': Decimal128('51.0798931')}}
# {'_id': ObjectId('643057f8130a14a279426967'), 'geocode': {'longitude': Decimal128('1.182125'), 'latitude': Decimal128('51.080412')}}
# {'_id': ObjectId('643057f8130a14a279426968'), 'geocode': {'longitude': Decimal128('1.182125'), 'latitude': Decimal128('51.080412')}}
# {'_id': ObjectId('643057f8130a14a279426969'), 'geocode': {'longitude': Decimal128('1.181482'), 'latitude': Decimal128('51.079799')}}
# {'_id': ObjectId('643057f8130a14a27942696a'), 'geocode': {'longitude': Decimal128('1.181483'), 'latitude': Decimal128('51.0798')}}
# {'_id': ObjectId('643057f8130a14a27942696b'), 'geocode': {'longitude': Decimal128('1.179446'), 'latitude': Decimal128('51.078209')}}
# {'_id': ObjectId('643057f8130a14a27942696c'), 'geocode': {'longitude': Decimal128('1.1813097'), 'latitude': Decimal128('51.0800235')}}
# {'_id': ObjectId('643057f8130a14a27942696d'), 'geocode': {'longitude': Decimal128('1.1814856'), 'latitude': Decimal128('51.0802346')}}
# {'_id': ObjectId('643057f8130a14a27942696e'), 'geocode': {'longitude': Decimal128('1.1810166'), 'latitude': Decimal128('51.0797886')}}
# {'_id': ObjectId('643057f8130a14a27942696f'), 'geocode': {'longitude': Decimal128('1.190904'), 'latitude': Decimal128('51.089491')}}
# {'_id': ObjectId('643057f8130a14a279426970'), 'geocode': {'longitude': Decimal128('1.190904'), 'latitude': Decimal128('51.089491')}}
# {'_id': ObjectId('643057f8130a14a279426971'), 'geocode': {'longitude': Decimal128('1.18172800540924'), 'latitude': Decimal128('51.0806732177734')}}
# {'_id': ObjectId('643057f8130a14a279426972'), 'geocode': {'longitude': Decimal128('1.181728'), 'latitude': Decimal128('51.080675')}}
# {'_id': ObjectId('643057f8130a14a279426973'), 'geocode': {'longitude': Decimal128('1.181728'), 'latitude': Decimal128('51.080675')}}
# {'_id': ObjectId('643057f8130a14a279426974'), 'geocode': {'longitude': Decimal128('1.181728'), 'latitude': Decimal128('51.080675')}}
# {'_id': ObjectId('643057f8130a14a279426975'), 'geocode': {'longitude': Decimal128('1.181728'), 'latitude': Decimal128('51.080675')}}
# {'_id': ObjectId('643057f8130a14a279426976'), 'geocode': {'longitude': Decimal128('1.181728'), 'latitude': Decimal128('51.080675')}}
# {'_id': ObjectId('643057f8130a14a279426977'), 'geocode': {'longitude': Decimal128('1.181728'), 'latitude': Decimal128('51.080675')}}
# {'_id': ObjectId('643057f8130a14a279426978'), 'geocode': {'longitude': Decimal128('1.1817227'), 'latitude': Decimal128('51.0806941')}}
# {'_id': ObjectId('643057f8130a14a279426979'), 'geocode': {'longitude': Decimal128('1.183327'), 'latitude': Decimal128('51.082322')}}
# {'_id': ObjectId('643057f8130a14a27942697a'), 'geocode': {'longitude': Decimal128('1.1802781'), 'latitude': Decimal128('51.0793698')}}
# {'_id': ObjectId('643057f8130a14a27942697b'), 'geocode': {'longitude': Decimal128('1.182609'), 'latitude': Decimal128('51.08164')}}
# {'_id': ObjectId('643057f8130a14a27942697c'), 'geocode': {'longitude': Decimal128('1.182609'), 'latitude': Decimal128('51.08164')}}
# {'_id': ObjectId('643057f8130a14a27942697d'), 'geocode': {'longitude': Decimal128('1.185011'), 'latitude': Decimal128('51.083976')}}
# {'_id': ObjectId('643057f8130a14a27942697e'), 'geocode': {'longitude': Decimal128('1.180437'), 'latitude': Decimal128('51.07954')}}
# {'_id': ObjectId('643057f8130a14a27942697f'), 'geocode': {'longitude': Decimal128('1.180437'), 'latitude': Decimal128('51.07954')}}
# {'_id': ObjectId('643057f8130a14a279426980'), 'geocode': {'longitude': Decimal128('1.180437'), 'latitude': Decimal128('51.07954')}}
# {'_id': ObjectId('643057f8130a14a279426981'), 'geocode': {'longitude': Decimal128('1.180437'), 'latitude': Decimal128('51.07954')}}
# {'_id': ObjectId('643057f8130a14a279426982'), 'geocode': {'longitude': Decimal128('1.1826116'), 'latitude': Decimal128('51.0816612')}}
# {'_id': ObjectId('643057f8130a14a279426983'), 'geocode': {'longitude': Decimal128('1.185748'), 'latitude': Decimal128('51.08472')}}
# {'_id': ObjectId('643057f8130a14a279426984'), 'geocode': {'longitude': Decimal128('1.185748'), 'latitude': Decimal128('51.084721')}}
# {'_id': ObjectId('643057f8130a14a279426985'), 'geocode': {'longitude': Decimal128('1.18279695510864'), 'latitude': Decimal128('51.0818634033203')}}
# {'_id': ObjectId('643057f8130a14a279426986'), 'geocode': {'longitude': Decimal128('1.181282'), 'latitude': Decimal128('51.080417')}}
# {'_id': ObjectId('643057f8130a14a279426987'), 'geocode': {'longitude': Decimal128('1.181282'), 'latitude': Decimal128('51.080417')}}
# {'_id': ObjectId('643057f8130a14a279426988'), 'geocode': {'longitude': Decimal128('1.18128204345703'), 'latitude': Decimal128('51.0804176330566')}}
# {'_id': ObjectId('643057f8130a14a279426989'), 'geocode': {'longitude': Decimal128('1.181023'), 'latitude': Decimal128('51.080181')}}
# {'_id': ObjectId('643057f8130a14a27942698a'), 'geocode': {'longitude': Decimal128('1.182753'), 'latitude': Decimal128('51.08187')}}
# {'_id': ObjectId('643057f8130a14a27942698b'), 'geocode': {'longitude': Decimal128('1.182753'), 'latitude': Decimal128('51.08187')}}
# {'_id': ObjectId('643057f8130a14a27942698c'), 'geocode': {'longitude': Decimal128('1.182753'), 'latitude': Decimal128('51.08187')}}
# {'_id': ObjectId('643057f8130a14a27942698d'), 'geocode': {'longitude': Decimal128('1.182356'), 'latitude': Decimal128('51.081494')}}
# {'_id': ObjectId('643057f8130a14a27942698e'), 'geocode': {'longitude': Decimal128('1.178909'), 'latitude': Decimal128('51.078296')}}
# {'_id': ObjectId('643057f8130a14a27942698f'), 'geocode': {'longitude': Decimal128('1.178909'), 'latitude': Decimal128('51.078296')}}
# {'_id': ObjectId('643057f8130a14a279426990'), 'geocode': {'longitude': Decimal128('1.178909'), 'latitude': Decimal128('51.078296')}}
# {'_id': ObjectId('643057f8130a14a279426991'), 'geocode': {'longitude': Decimal128('1.178909'), 'latitude': Decimal128('51.078296')}}
# {'_id': ObjectId('643057f8130a14a279426992'), 'geocode': {'longitude': Decimal128('1.186241'), 'latitude': Decimal128('51.085454')}}
# {'_id': ObjectId('643057f8130a14a279426993'), 'geocode': {'longitude': Decimal128('1.186977'), 'latitude': Decimal128('51.086189')}}
# {'_id': ObjectId('643057f8130a14a279426994'), 'geocode': {'longitude': Decimal128('1.186977'), 'latitude': Decimal128('51.086189')}}
# {'_id': ObjectId('643057f8130a14a279426995'), 'geocode': {'longitude': Decimal128('1.17911505699158'), 'latitude': Decimal128('51.0785865783691')}}
# {'_id': ObjectId('643057f8130a14a279426996'), 'geocode': {'longitude': Decimal128('1.179115'), 'latitude': Decimal128('51.078587')}}
# {'_id': ObjectId('643057f8130a14a279426997'), 'geocode': {'longitude': Decimal128('1.1785097'), 'latitude': Decimal128('51.0780695')}}
# {'_id': ObjectId('643057f8130a14a279426998'), 'geocode': {'longitude': Decimal128('1.1803396'), 'latitude': Decimal128('51.0798709')}}
# {'_id': ObjectId('643057f8130a14a279426999'), 'geocode': {'longitude': Decimal128('1.1806797'), 'latitude': Decimal128('51.0802287')}}
# {'_id': ObjectId('643057f8130a14a27942699a'), 'geocode': {'longitude': Decimal128('1.1784815'), 'latitude': Decimal128('51.078117')}}
# {'_id': ObjectId('643057f8130a14a27942699b'), 'geocode': {'longitude': Decimal128('1.1783613'), 'latitude': Decimal128('51.0781968')}}
# {'_id': ObjectId('643057f8130a14a27942699c'), 'geocode': {'longitude': Decimal128('1.1783613'), 'latitude': Decimal128('51.0781968')}}
# {'_id': ObjectId('643057f8130a14a27942699d'), 'geocode': {'longitude': Decimal128('1.179729'), 'latitude': Decimal128('51.079632')}}
# {'_id': ObjectId('643057f8130a14a27942699e'), 'geocode': {'longitude': Decimal128('1.179729'), 'latitude': Decimal128('51.079632')}}
# {'_id': ObjectId('643057f8130a14a27942699f'), 'geocode': {'longitude': Decimal128('1.183784'), 'latitude': Decimal128('51.083569')}}
# {'_id': ObjectId('643057f8130a14a2794269a0'), 'geocode': {'longitude': Decimal128('1.183784'), 'latitude': Decimal128('51.083569')}}
# {'_id': ObjectId('643057f8130a14a2794269a1'), 'geocode': {'longitude': Decimal128('1.18039'), 'latitude': Decimal128('51.080315')}}
# {'_id': ObjectId('643057f8130a14a2794269a2'), 'geocode': {'longitude': Decimal128('1.18039'), 'latitude': Decimal128('51.080315')}}
# {'_id': ObjectId('643057f8130a14a2794269a3'), 'geocode': {'longitude': Decimal128('1.178027'), 'latitude': Decimal128('51.078131')}}
# {'_id': ObjectId('643057f8130a14a2794269a4'), 'geocode': {'longitude': Decimal128('1.1818685'), 'latitude': Decimal128('51.0818613')}}
# {'_id': ObjectId('643057f8130a14a2794269a5'), 'geocode': {'longitude': Decimal128('1.1818685'), 'latitude': Decimal128('51.0818613')}}
# {'_id': ObjectId('643057f8130a14a2794269a8'), 'geocode': {'longitude': Decimal128('1.179926'), 'latitude': Decimal128('51.080211')}}
# {'_id': ObjectId('643057f8130a14a2794269a9'), 'geocode': {'longitude': Decimal128('1.179926'), 'latitude': Decimal128('51.080211')}}
# {'_id': ObjectId('643057f8130a14a2794269aa'), 'geocode': {'longitude': Decimal128('1.179925'), 'latitude': Decimal128('51.080211')}}
# {'_id': ObjectId('643057f8130a14a2794269ab'), 'geocode': {'longitude': Decimal128('1.17884'), 'latitude': Decimal128('51.079161')}}
# {'_id': ObjectId('643057f8130a14a2794269ac'), 'geocode': {'longitude': Decimal128('1.1799178'), 'latitude': Decimal128('51.080217')}}
# {'_id': ObjectId('643057f8130a14a2794269ad'), 'geocode': {'longitude': Decimal128('1.181201'), 'latitude': Decimal128('51.081526')}}
# {'_id': ObjectId('643057f8130a14a2794269ae'), 'geocode': {'longitude': Decimal128('1.178961'), 'latitude': Decimal128('51.079481')}}
# {'_id': ObjectId('643057f8130a14a2794269af'), 'geocode': {'longitude': Decimal128('1.178962'), 'latitude': Decimal128('51.079482')}}
# {'_id': ObjectId('643057f8130a14a2794269b0'), 'geocode': {'longitude': Decimal128('1.178962'), 'latitude': Decimal128('51.079482')}}
# {'_id': ObjectId('643057f8130a14a2794269b1'), 'geocode': {'longitude': Decimal128('1.180846'), 'latitude': Decimal128('51.081337')}}
# {'_id': ObjectId('643057f8130a14a2794269b2'), 'geocode': {'longitude': Decimal128('1.180846'), 'latitude': Decimal128('51.081337')}}
# {'_id': ObjectId('643057f8130a14a2794269b3'), 'geocode': {'longitude': Decimal128('1.177752'), 'latitude': Decimal128('51.0783483')}}
# {'_id': ObjectId('643057f8130a14a2794269b5'), 'geocode': {'longitude': Decimal128('1.1776046'), 'latitude': Decimal128('51.0783433')}}
# {'_id': ObjectId('643057f8130a14a2794269b6'), 'geocode': {'longitude': Decimal128('1.188295'), 'latitude': Decimal128('51.088735')}}
# {'_id': ObjectId('643057f8130a14a2794269b7'), 'geocode': {'longitude': Decimal128('1.188295'), 'latitude': Decimal128('51.088735')}}
# {'_id': ObjectId('643057f8130a14a2794269b8'), 'geocode': {'longitude': Decimal128('1.1817418'), 'latitude': Decimal128('51.0824157')}}
# {'_id': ObjectId('643057f8130a14a2794269b9'), 'geocode': {'longitude': Decimal128('1.177468'), 'latitude': Decimal128('51.078317')}}
# {'_id': ObjectId('643057f8130a14a2794269ba'), 'geocode': {'longitude': Decimal128('1.177468'), 'latitude': Decimal128('51.078317')}}
# {'_id': ObjectId('643057f8130a14a2794269bb'), 'geocode': {'longitude': Decimal128('1.177468'), 'latitude': Decimal128('51.078317')}}
# {'_id': ObjectId('643057f8130a14a2794269bc'), 'geocode': {'longitude': Decimal128('1.177468'), 'latitude': Decimal128('51.078317')}}
# {'_id': ObjectId('643057f8130a14a2794269bd'), 'geocode': {'longitude': Decimal128('1.182136'), 'latitude': Decimal128('51.082867')}}
# {'_id': ObjectId('643057f8130a14a2794269be'), 'geocode': {'longitude': Decimal128('1.182136'), 'latitude': Decimal128('51.082867')}}
# {'_id': ObjectId('643057f8130a14a2794269c0'), 'geocode': {'longitude': Decimal128('1.186371'), 'latitude': Decimal128('51.087132')}}
# {'_id': ObjectId('643057f8130a14a2794269c1'), 'geocode': {'longitude': Decimal128('1.1796215'), 'latitude': Decimal128('51.0806446')}}
# {'_id': ObjectId('643057f8130a14a2794269c2'), 'geocode': {'longitude': Decimal128('1.179628'), 'latitude': Decimal128('51.080668')}}
# {'_id': ObjectId('643057f8130a14a2794269c3'), 'geocode': {'longitude': Decimal128('1.179629'), 'latitude': Decimal128('51.080669')}}
# {'_id': ObjectId('643057f8130a14a2794269c4'), 'geocode': {'longitude': Decimal128('1.179629'), 'latitude': Decimal128('51.080669')}}
# {'_id': ObjectId('643057f8130a14a2794269c5'), 'geocode': {'longitude': Decimal128('1.1794011'), 'latitude': Decimal128('51.0804496')}}
# {'_id': ObjectId('643057f8130a14a2794269c6'), 'geocode': {'longitude': Decimal128('1.181896'), 'latitude': Decimal128('51.083108')}}
# {'_id': ObjectId('643057f8130a14a2794269c7'), 'geocode': {'longitude': Decimal128('1.175486'), 'latitude': Decimal128('51.076896')}}
# {'_id': ObjectId('643057f8130a14a2794269c8'), 'geocode': {'longitude': Decimal128('1.176733'), 'latitude': Decimal128('51.078211')}}
# {'_id': ObjectId('643057f8130a14a2794269c9'), 'geocode': {'longitude': Decimal128('1.17673301696777'), 'latitude': Decimal128('51.0782127380371')}}
# {'_id': ObjectId('643057f8130a14a2794269ca'), 'geocode': {'longitude': Decimal128('1.1794486'), 'latitude': Decimal128('51.0808513')}}
# {'_id': ObjectId('643057f8130a14a2794269cb'), 'geocode': {'longitude': Decimal128('1.17957198619843'), 'latitude': Decimal128('51.0810699462891')}}
# {'_id': ObjectId('643057f8130a14a2794269cc'), 'geocode': {'longitude': Decimal128('1.177506'), 'latitude': Decimal128('51.079081')}}
# {'_id': ObjectId('643057f8130a14a2794269cd'), 'geocode': {'longitude': Decimal128('1.177506'), 'latitude': Decimal128('51.079081')}}
# {'_id': ObjectId('643057f8130a14a2794269ce'), 'geocode': {'longitude': Decimal128('1.178969'), 'latitude': Decimal128('51.080624')}}
# {'_id': ObjectId('643057f8130a14a2794269cf'), 'geocode': {'longitude': Decimal128('1.17799'), 'latitude': Decimal128('51.079679')}}
# {'_id': ObjectId('643057f8130a14a2794269d0'), 'geocode': {'longitude': Decimal128('1.17799'), 'latitude': Decimal128('51.079679')}}
# {'_id': ObjectId('643057f8130a14a2794269d1'), 'geocode': {'longitude': Decimal128('1.17799'), 'latitude': Decimal128('51.079679')}}
# {'_id': ObjectId('643057f8130a14a2794269d2'), 'geocode': {'longitude': Decimal128('1.17799'), 'latitude': Decimal128('51.079679')}}
# {'_id': ObjectId('643057f8130a14a2794269d3'), 'geocode': {'longitude': Decimal128('1.174813'), 'latitude': Decimal128('51.076653')}}
# {'_id': ObjectId('643057f8130a14a2794269d4'), 'geocode': {'longitude': Decimal128('1.17575001716614'), 'latitude': Decimal128('51.0776252746582')}}
# {'_id': ObjectId('643057f8130a14a2794269d5'), 'geocode': {'longitude': Decimal128('1.17575'), 'latitude': Decimal128('51.077626')}}
# {'_id': ObjectId('643057f8130a14a2794269d6'), 'geocode': {'longitude': Decimal128('1.17575'), 'latitude': Decimal128('51.077626')}}
# {'_id': ObjectId('643057f8130a14a2794269d7'), 'geocode': {'longitude': Decimal128('1.17575'), 'latitude': Decimal128('51.077626')}}
# {'_id': ObjectId('643057f8130a14a2794269d8'), 'geocode': {'longitude': Decimal128('1.17575'), 'latitude': Decimal128('51.077626')}}
# {'_id': ObjectId('643057f8130a14a2794269d9'), 'geocode': {'longitude': Decimal128('1.17575'), 'latitude': Decimal128('51.077626')}}
# {'_id': ObjectId('643057f8130a14a2794269da'), 'geocode': {'longitude': Decimal128('1.185418'), 'latitude': Decimal128('51.087185')}}
# {'_id': ObjectId('643057f8130a14a2794269db'), 'geocode': {'longitude': Decimal128('1.17352676391602'), 'latitude': Decimal128('51.0758056640625')}}
# {'_id': ObjectId('643057f8130a14a2794269dc'), 'geocode': {'longitude': Decimal128('1.1753663'), 'latitude': Decimal128('51.0776458')}}
# {'_id': ObjectId('643057f8130a14a2794269dd'), 'geocode': {'longitude': Decimal128('1.174605'), 'latitude': Decimal128('51.076956')}}
# {'_id': ObjectId('643057f8130a14a2794269de'), 'geocode': {'longitude': Decimal128('1.174605'), 'latitude': Decimal128('51.076956')}}
# {'_id': ObjectId('643057f8130a14a2794269df'), 'geocode': {'longitude': Decimal128('1.176296'), 'latitude': Decimal128('51.078718')}}
# {'_id': ObjectId('643057f8130a14a2794269e0'), 'geocode': {'longitude': Decimal128('1.176296'), 'latitude': Decimal128('51.078718')}}
# {'_id': ObjectId('643057f8130a14a2794269e1'), 'geocode': {'longitude': Decimal128('1.176258'), 'latitude': Decimal128('51.07879')}}
# {'_id': ObjectId('643057f8130a14a2794269e2'), 'geocode': {'longitude': Decimal128('1.175897'), 'latitude': Decimal128('51.078513')}}
# {'_id': ObjectId('643057f8130a14a2794269e3'), 'geocode': {'longitude': Decimal128('1.1762215'), 'latitude': Decimal128('51.0788531')}}
# {'_id': ObjectId('643057f8130a14a2794269e4'), 'geocode': {'longitude': Decimal128('1.17535'), 'latitude': Decimal128('51.078033')}}
# {'_id': ObjectId('643057f8130a14a2794269e5'), 'geocode': {'longitude': Decimal128('1.17535'), 'latitude': Decimal128('51.078033')}}
# {'_id': ObjectId('643057f8130a14a2794269e6'), 'geocode': {'longitude': Decimal128('1.17535'), 'latitude': Decimal128('51.078033')}}
# {'_id': ObjectId('643057f8130a14a2794269e7'), 'geocode': {'longitude': Decimal128('1.17535'), 'latitude': Decimal128('51.078033')}}
# {'_id': ObjectId('643057f8130a14a2794269e8'), 'geocode': {'longitude': Decimal128('1.17535'), 'latitude': Decimal128('51.078033')}}
# {'_id': ObjectId('643057f8130a14a2794269e9'), 'geocode': {'longitude': Decimal128('1.175811'), 'latitude': Decimal128('51.078515')}}
# {'_id': ObjectId('643057f8130a14a2794269ea'), 'geocode': {'longitude': Decimal128('1.175811'), 'latitude': Decimal128('51.078515')}}
# {'_id': ObjectId('643057f8130a14a2794269eb'), 'geocode': {'longitude': Decimal128('1.189834'), 'latitude': Decimal128('51.09221')}}
# {'_id': ObjectId('643057f8130a14a2794269ec'), 'geocode': {'longitude': Decimal128('1.189833'), 'latitude': Decimal128('51.09221')}}
# {'_id': ObjectId('643057f8130a14a2794269ed'), 'geocode': {'longitude': Decimal128('1.17591404914856'), 'latitude': Decimal128('51.0787391662598')}}
# {'_id': ObjectId('643057f8130a14a2794269ee'), 'geocode': {'longitude': Decimal128('1.184803'), 'latitude': Decimal128('51.087382')}}
# {'_id': ObjectId('643057f8130a14a2794269ef'), 'geocode': {'longitude': Decimal128('1.17584'), 'latitude': Decimal128('51.07873')}}
# {'_id': ObjectId('643057f8130a14a2794269f0'), 'geocode': {'longitude': Decimal128('1.17584'), 'latitude': Decimal128('51.07873')}}
# {'_id': ObjectId('643057f8130a14a2794269f1'), 'geocode': {'longitude': Decimal128('1.17584'), 'latitude': Decimal128('51.07873')}}
# {'_id': ObjectId('643057f8130a14a2794269f2'), 'geocode': {'longitude': Decimal128('1.17584'), 'latitude': Decimal128('51.07873')}}
# {'_id': ObjectId('643057f8130a14a2794269f3'), 'geocode': {'longitude': Decimal128('1.17841398715973'), 'latitude': Decimal128('51.0812644958496')}}
# {'_id': ObjectId('643057f8130a14a2794269f4'), 'geocode': {'longitude': Decimal128('1.17725700019713'), 'latitude': Decimal128('51.0806630002457')}}
# {'_id': ObjectId('643057f8130a14a2794269f5'), 'geocode': {'longitude': Decimal128('1.1748'), 'latitude': Decimal128('51.07856')}}
# {'_id': ObjectId('643057f8130a14a2794269f6'), 'geocode': {'longitude': Decimal128('1.172728'), 'latitude': Decimal128('51.076647')}}
# {'_id': ObjectId('643057f8130a14a2794269f7'), 'geocode': {'longitude': Decimal128('1.172728'), 'latitude': Decimal128('51.076647')}}
# {'_id': ObjectId('643057f8130a14a2794269f8'), 'geocode': {'longitude': Decimal128('1.172728'), 'latitude': Decimal128('51.076647')}}
# {'_id': ObjectId('643057f8130a14a2794269f9'), 'geocode': {'longitude': Decimal128('1.18431'), 'latitude': Decimal128('51.088115')}}
# {'_id': ObjectId('643057f8130a14a2794269fa'), 'geocode': {'longitude': Decimal128('1.18431'), 'latitude': Decimal128('51.088115')}}
# {'_id': ObjectId('643057f8130a14a2794269fb'), 'geocode': {'longitude': Decimal128('1.18431'), 'latitude': Decimal128('51.088115')}}
# {'_id': ObjectId('643057f8130a14a2794269fc'), 'geocode': {'longitude': Decimal128('1.18431'), 'latitude': Decimal128('51.088115')}}
# {'_id': ObjectId('643057f8130a14a2794269fd'), 'geocode': {'longitude': Decimal128('1.18431'), 'latitude': Decimal128('51.088115')}}
# {'_id': ObjectId('643057f8130a14a2794269fe'), 'geocode': {'longitude': Decimal128('1.18431'), 'latitude': Decimal128('51.088115')}}
# {'_id': ObjectId('643057f8130a14a2794269ff'), 'geocode': {'longitude': Decimal128('1.1842719'), 'latitude': Decimal128('51.0881644')}}
# {'_id': ObjectId('643057f8130a14a279426a00'), 'geocode': {'longitude': Decimal128('1.172055'), 'latitude': Decimal128('51.076413')}}
# {'_id': ObjectId('643057f8130a14a279426a01'), 'geocode': {'longitude': Decimal128('1.174748'), 'latitude': Decimal128('51.079039')}}
# {'_id': ObjectId('643057f8130a14a279426a02'), 'geocode': {'longitude': Decimal128('1.173056'), 'latitude': Decimal128('51.077492')}}
# {'_id': ObjectId('643057f8130a14a279426a03'), 'geocode': {'longitude': Decimal128('1.175782'), 'latitude': Decimal128('51.080171')}}
# {'_id': ObjectId('643057f8130a14a279426a04'), 'geocode': {'longitude': Decimal128('1.175782'), 'latitude': Decimal128('51.080171')}}
# {'_id': ObjectId('643057f8130a14a279426a05'), 'geocode': {'longitude': Decimal128('1.17198'), 'latitude': Decimal128('51.076577')}}
# {'_id': ObjectId('643057f8130a14a279426a06'), 'geocode': {'longitude': Decimal128('1.17198'), 'latitude': Decimal128('51.076577')}}
# {'_id': ObjectId('643057f8130a14a279426a07'), 'geocode': {'longitude': Decimal128('1.183925'), 'latitude': Decimal128('51.088333')}}
# {'_id': ObjectId('643057f8130a14a279426a08'), 'geocode': {'longitude': Decimal128('1.172652'), 'latitude': Decimal128('51.077414')}}
# {'_id': ObjectId('643057f8130a14a279426a09'), 'geocode': {'longitude': Decimal128('1.172652'), 'latitude': Decimal128('51.077414')}}
# {'_id': ObjectId('643057f8130a14a279426a0a'), 'geocode': {'longitude': Decimal128('1.185859'), 'latitude': Decimal128('51.090286')}}
# {'_id': ObjectId('643057f8130a14a279426a0b'), 'geocode': {'longitude': Decimal128('1.18468'), 'latitude': Decimal128('51.089337')}}
# {'_id': ObjectId('643057f8130a14a279426a0c'), 'geocode': {'longitude': Decimal128('1.1784191'), 'latitude': Decimal128('51.0833323')}}
# {'_id': ObjectId('643057f8130a14a279426a0d'), 'geocode': {'longitude': Decimal128('1.186289'), 'latitude': Decimal128('51.091129')}}
# {'_id': ObjectId('643057f8130a14a279426a0e'), 'geocode': {'longitude': Decimal128('1.172314'), 'latitude': Decimal128('51.077702')}}
# {'_id': ObjectId('643057f8130a14a279426a0f'), 'geocode': {'longitude': Decimal128('1.16866'), 'latitude': Decimal128('51.074167')}}
# {'_id': ObjectId('643057f8130a14a279426a11'), 'geocode': {'longitude': Decimal128('1.172619'), 'latitude': Decimal128('51.078197')}}
# {'_id': ObjectId('643057f8130a14a279426a12'), 'geocode': {'longitude': Decimal128('1.172619'), 'latitude': Decimal128('51.078197')}}
# {'_id': ObjectId('643057f8130a14a279426a13'), 'geocode': {'longitude': Decimal128('1.172619'), 'latitude': Decimal128('51.078197')}}
# {'_id': ObjectId('643057f8130a14a279426a14'), 'geocode': {'longitude': Decimal128('1.172619'), 'latitude': Decimal128('51.078197')}}
# {'_id': ObjectId('643057f8130a14a279426a15'), 'geocode': {'longitude': Decimal128('1.172619'), 'latitude': Decimal128('51.078197')}}
# {'_id': ObjectId('643057f8130a14a279426a16'), 'geocode': {'longitude': Decimal128('1.172619'), 'latitude': Decimal128('51.078197')}}
# {'_id': ObjectId('643057f8130a14a279426a17'), 'geocode': {'longitude': Decimal128('1.172619'), 'latitude': Decimal128('51.078197')}}
# {'_id': ObjectId('643057f8130a14a279426a18'), 'geocode': {'longitude': Decimal128('1.172619'), 'latitude': Decimal128('51.078197')}}
# {'_id': ObjectId('643057f8130a14a279426a19'), 'geocode': {'longitude': Decimal128('1.177367'), 'latitude': Decimal128('51.082871')}}
# {'_id': ObjectId('643057f8130a14a279426a1a'), 'geocode': {'longitude': Decimal128('1.173416'), 'latitude': Decimal128('51.079192')}}
# {'_id': ObjectId('643057f8130a14a279426a1b'), 'geocode': {'longitude': Decimal128('1.172054'), 'latitude': Decimal128('51.078068')}}
# {'_id': ObjectId('643057f8130a14a279426a1c'), 'geocode': {'longitude': Decimal128('1.176219'), 'latitude': Decimal128('51.082381')}}
# {'_id': ObjectId('643057f8130a14a279426a1d'), 'geocode': {'longitude': Decimal128('1.172452'), 'latitude': Decimal128('51.078885')}}
# {'_id': ObjectId('643057f8130a14a279426a1e'), 'geocode': {'longitude': Decimal128('1.174678'), 'latitude': Decimal128('51.081154')}}
# {'_id': ObjectId('643057f8130a14a279426a1f'), 'geocode': {'longitude': Decimal128('1.169515'), 'latitude': Decimal128('51.07623')}}
# {'_id': ObjectId('643057f8130a14a279426a20'), 'geocode': {'longitude': Decimal128('1.169515'), 'latitude': Decimal128('51.07623')}}
# {'_id': ObjectId('643057f8130a14a279426a21'), 'geocode': {'longitude': Decimal128('1.168516'), 'latitude': Decimal128('51.075403')}}
# {'_id': ObjectId('643057f8130a14a279426a22'), 'geocode': {'longitude': Decimal128('1.171552'), 'latitude': Decimal128('51.078874')}}
# {'_id': ObjectId('643057f8130a14a279426a23'), 'geocode': {'longitude': Decimal128('1.177755'), 'latitude': Decimal128('51.085001')}}
# {'_id': ObjectId('643057f8130a14a279426a24'), 'geocode': {'longitude': Decimal128('1.177729'), 'latitude': Decimal128('51.085038')}}
# {'_id': ObjectId('643057f8130a14a279426a25'), 'geocode': {'longitude': Decimal128('1.177729'), 'latitude': Decimal128('51.085038')}}
# {'_id': ObjectId('643057f8130a14a279426a26'), 'geocode': {'longitude': Decimal128('1.177729'), 'latitude': Decimal128('51.085038')}}
# {'_id': ObjectId('643057f8130a14a279426a27'), 'geocode': {'longitude': Decimal128('1.181507'), 'latitude': Decimal128('51.088893')}}
# {'_id': ObjectId('643057f8130a14a279426a28'), 'geocode': {'longitude': Decimal128('1.17363'), 'latitude': Decimal128('51.08129')}}
# {'_id': ObjectId('643057f8130a14a279426a29'), 'geocode': {'longitude': Decimal128('1.173631'), 'latitude': Decimal128('51.081291')}}
# {'_id': ObjectId('643057f8130a14a279426a2a'), 'geocode': {'longitude': Decimal128('1.173631'), 'latitude': Decimal128('51.081291')}}
# {'_id': ObjectId('643057f8130a14a279426a2b'), 'geocode': {'longitude': Decimal128('1.168984'), 'latitude': Decimal128('51.077243')}}
# {'_id': ObjectId('643057f8130a14a279426a2c'), 'geocode': {'longitude': Decimal128('1.17373'), 'latitude': Decimal128('51.0819')}}
# {'_id': ObjectId('643057f8130a14a279426a2d'), 'geocode': {'longitude': Decimal128('1.178428'), 'latitude': Decimal128('51.086485')}}
# {'_id': ObjectId('643057f8130a14a279426a2e'), 'geocode': {'longitude': Decimal128('1.179997'), 'latitude': Decimal128('51.088124')}}
# {'_id': ObjectId('643057f8130a14a279426a2f'), 'geocode': {'longitude': Decimal128('1.179998'), 'latitude': Decimal128('51.088125')}}
# {'_id': ObjectId('643057f8130a14a279426a30'), 'geocode': {'longitude': Decimal128('1.178766'), 'latitude': Decimal128('51.087034')}}
# {'_id': ObjectId('643057f8130a14a279426a31'), 'geocode': {'longitude': Decimal128('1.178766'), 'latitude': Decimal128('51.087034')}}
# {'_id': ObjectId('643057f8130a14a279426a32'), 'geocode': {'longitude': Decimal128('1.178766'), 'latitude': Decimal128('51.087034')}}
# {'_id': ObjectId('643057f8130a14a279426a33'), 'geocode': {'longitude': Decimal128('1.172065'), 'latitude': Decimal128('51.080533')}}
# {'_id': ObjectId('643057f8130a14a279426a34'), 'geocode': {'longitude': Decimal128('1.177515'), 'latitude': Decimal128('51.085872')}}
# {'_id': ObjectId('643057f8130a14a279426a36'), 'geocode': {'longitude': Decimal128('1.176952'), 'latitude': Decimal128('51.085365')}}
# {'_id': ObjectId('643057f8130a14a279426a37'), 'geocode': {'longitude': Decimal128('1.171635'), 'latitude': Decimal128('51.080302')}}
# {'_id': ObjectId('643057f8130a14a279426a39'), 'geocode': {'longitude': Decimal128('1.181609'), 'latitude': Decimal128('51.090168')}}
# {'_id': ObjectId('643057f8130a14a279426a3a'), 'geocode': {'longitude': Decimal128('1.168302'), 'latitude': Decimal128('51.077289')}}
# {'_id': ObjectId('643057f8130a14a279426a3b'), 'geocode': {'longitude': Decimal128('1.180133'), 'latitude': Decimal128('51.08885')}}
# {'_id': ObjectId('643057f8130a14a279426a3c'), 'geocode': {'longitude': Decimal128('1.180073'), 'latitude': Decimal128('51.088806')}}
# {'_id': ObjectId('643057f8130a14a279426a3d'), 'geocode': {'longitude': Decimal128('1.173059'), 'latitude': Decimal128('51.082331')}}
# {'_id': ObjectId('643057f8130a14a279426a3e'), 'geocode': {'longitude': Decimal128('1.17306'), 'latitude': Decimal128('51.082332')}}
# {'_id': ObjectId('643057f8130a14a279426a3f'), 'geocode': {'longitude': Decimal128('1.172295'), 'latitude': Decimal128('51.081795')}}
# {'_id': ObjectId('643057f8130a14a279426a40'), 'geocode': {'longitude': Decimal128('1.18094'), 'latitude': Decimal128('51.090195')}}
# {'_id': ObjectId('643057f8130a14a279426a41'), 'geocode': {'longitude': Decimal128('1.167704'), 'latitude': Decimal128('51.077737')}}
# {'_id': ObjectId('643057f8130a14a279426a42'), 'geocode': {'longitude': Decimal128('1.165413'), 'latitude': Decimal128('51.07555')}}
# {'_id': ObjectId('643057f8130a14a279426a43'), 'geocode': {'longitude': Decimal128('1.1665238'), 'latitude': Decimal128('51.0769439')}}
# {'_id': ObjectId('643057f8130a14a279426a44'), 'geocode': {'longitude': Decimal128('1.171556'), 'latitude': Decimal128('51.08186')}}
# {'_id': ObjectId('643057f8130a14a279426a45'), 'geocode': {'longitude': Decimal128('1.175336'), 'latitude': Decimal128('51.085552')}}
# {'_id': ObjectId('643057f8130a14a279426a46'), 'geocode': {'longitude': Decimal128('1.175337'), 'latitude': Decimal128('51.085553')}}
# {'_id': ObjectId('643057f8130a14a279426a47'), 'geocode': {'longitude': Decimal128('1.1829433'), 'latitude': Decimal128('51.0932246')}}
# {'_id': ObjectId('643057f8130a14a279426a48'), 'geocode': {'longitude': Decimal128('1.17090594768524'), 'latitude': Decimal128('51.0817527770996')}}
# {'_id': ObjectId('643057f8130a14a279426a49'), 'geocode': {'longitude': Decimal128('1.171506'), 'latitude': Decimal128('51.082374')}}
# {'_id': ObjectId('643057f8130a14a279426a4a'), 'geocode': {'longitude': Decimal128('1.171506'), 'latitude': Decimal128('51.082374')}}
# {'_id': ObjectId('643057f8130a14a279426a4b'), 'geocode': {'longitude': Decimal128('1.171506'), 'latitude': Decimal128('51.082374')}}
# {'_id': ObjectId('643057f8130a14a279426a4e'), 'geocode': {'longitude': Decimal128('1.16350066661835'), 'latitude': Decimal128('51.0751419067383')}}
# {'_id': ObjectId('643057f8130a14a279426a4f'), 'geocode': {'longitude': Decimal128('1.164581'), 'latitude': Decimal128('51.076949')}}
# {'_id': ObjectId('643057f8130a14a279426a50'), 'geocode': {'longitude': Decimal128('1.17163395881653'), 'latitude': Decimal128('51.083812713623')}}
# {'_id': ObjectId('643057f8130a14a279426a51'), 'geocode': {'longitude': Decimal128('1.171591'), 'latitude': Decimal128('51.08382')}}
# {'_id': ObjectId('643057f8130a14a279426a52'), 'geocode': {'longitude': Decimal128('1.162196'), 'latitude': Decimal128('51.07507')}}
# {'_id': ObjectId('643057f8130a14a279426a53'), 'geocode': {'longitude': Decimal128('1.182639'), 'latitude': Decimal128('51.095177')}}
# {'_id': ObjectId('643057f8130a14a279426a54'), 'geocode': {'longitude': Decimal128('1.182639'), 'latitude': Decimal128('51.095177')}}
# {'_id': ObjectId('643057f8130a14a279426a55'), 'geocode': {'longitude': Decimal128('1.182639'), 'latitude': Decimal128('51.095177')}}
# {'_id': ObjectId('643057f8130a14a279426a56'), 'geocode': {'longitude': Decimal128('1.182639'), 'latitude': Decimal128('51.095177')}}
# {'_id': ObjectId('643057f8130a14a279426a57'), 'geocode': {'longitude': Decimal128('1.172865'), 'latitude': Decimal128('51.085755')}}
# {'_id': ObjectId('643057f8130a14a279426a58'), 'geocode': {'longitude': Decimal128('1.165543'), 'latitude': Decimal128('51.078911')}}
# {'_id': ObjectId('643057f8130a14a279426a59'), 'geocode': {'longitude': Decimal128('1.171755'), 'latitude': Decimal128('51.08538')}}
# {'_id': ObjectId('643057f8130a14a279426a5b'), 'geocode': {'longitude': Decimal128('1.168524'), 'latitude': Decimal128('51.082833')}}
# {'_id': ObjectId('643057f8130a14a279426a61'), 'geocode': {'longitude': Decimal128('1.164533'), 'latitude': Decimal128('51.080017')}}
# {'_id': ObjectId('643057f8130a14a279426a62'), 'geocode': {'longitude': Decimal128('1.171919'), 'latitude': Decimal128('51.087373')}}
# {'_id': ObjectId('643057f8130a14a279426a63'), 'geocode': {'longitude': Decimal128('1.171919'), 'latitude': Decimal128('51.087373')}}
# {'_id': ObjectId('643057f8130a14a279426a64'), 'geocode': {'longitude': Decimal128('1.16362'), 'latitude': Decimal128('51.079404')}}
# {'_id': ObjectId('643057f8130a14a279426a67'), 'geocode': {'longitude': Decimal128('1.160028'), 'latitude': Decimal128('51.076559')}}
# {'_id': ObjectId('643057f8130a14a279426a68'), 'geocode': {'longitude': Decimal128('1.165969'), 'latitude': Decimal128('51.082434')}}
# {'_id': ObjectId('643057f8130a14a279426a6c'), 'geocode': {'longitude': Decimal128('1.168597'), 'latitude': Decimal128('51.085565')}}
# {'_id': ObjectId('643057f8130a14a279426a6d'), 'geocode': {'longitude': Decimal128('1.16422498226166'), 'latitude': Decimal128('51.0813407897949')}}
# {'_id': ObjectId('643057f8130a14a279426a6e'), 'geocode': {'longitude': Decimal128('1.164182'), 'latitude': Decimal128('51.081358')}}
# {'_id': ObjectId('643057f8130a14a279426a70'), 'geocode': {'longitude': Decimal128('1.166898'), 'latitude': Decimal128('51.084325')}}
# {'_id': ObjectId('643057f8130a14a279426a71'), 'geocode': {'longitude': Decimal128('1.166898'), 'latitude': Decimal128('51.084325')}}
# {'_id': ObjectId('643057f8130a14a279426a72'), 'geocode': {'longitude': Decimal128('1.173128'), 'latitude': Decimal128('51.090416')}}
# {'_id': ObjectId('643057f8130a14a279426a73'), 'geocode': {'longitude': Decimal128('1.173128'), 'latitude': Decimal128('51.090416')}}
# {'_id': ObjectId('643057f8130a14a279426a74'), 'geocode': {'longitude': Decimal128('1.42664802074432'), 'latitude': Decimal128('51.3344841003418')}}
# {'_id': ObjectId('643057f8130a14a279426a75'), 'geocode': {'longitude': Decimal128('1.427746'), 'latitude': Decimal128('51.335713')}}
# {'_id': ObjectId('643057f8130a14a279426a76'), 'geocode': {'longitude': Decimal128('1.427746'), 'latitude': Decimal128('51.335713')}}
# {'_id': ObjectId('643057f8130a14a279426a77'), 'geocode': {'longitude': Decimal128('1.428762'), 'latitude': Decimal128('51.336816')}}
# {'_id': ObjectId('643057f8130a14a279426a78'), 'geocode': {'longitude': Decimal128('1.167918'), 'latitude': Decimal128('51.085871')}}
# {'_id': ObjectId('643057f8130a14a279426a79'), 'geocode': {'longitude': Decimal128('1.158282'), 'latitude': Decimal128('51.076715')}}
# {'_id': ObjectId('643057f8130a14a279426a7a'), 'geocode': {'longitude': Decimal128('1.429786'), 'latitude': Decimal128('51.338414')}}
# {'_id': ObjectId('643057f8130a14a279426a7b'), 'geocode': {'longitude': Decimal128('1.429786'), 'latitude': Decimal128('51.338414')}}
# {'_id': ObjectId('643057f8130a14a279426a7d'), 'geocode': {'longitude': Decimal128('1.42320394515991'), 'latitude': Decimal128('51.3322105407715')}}
# {'_id': ObjectId('643057f8130a14a279426a7e'), 'geocode': {'longitude': Decimal128('1.423192'), 'latitude': Decimal128('51.33222')}}
# ...
# {'_id': ObjectId('643057fd130a14a279430103'), 'geocode': {'longitude': Decimal128('0.231484994292259'), 'latitude': Decimal128('52.017147064209')}}
# {'_id': ObjectId('643057fd130a14a279430104'), 'geocode': {'longitude': Decimal128('0.231484994292259'), 'latitude': Decimal128('52.017147064209')}}
# {'_id': ObjectId('643057fd130a14a279430105'), 'geocode': {'longitude': Decimal128('0.231484'), 'latitude': Decimal128('52.017148')}}
# {'_id': ObjectId('643057fd130a14a279430106'), 'geocode': {'longitude': Decimal128('0.231484'), 'latitude': Decimal128('52.017148')}}
# {'_id': ObjectId('643057fd130a14a279430107'), 'geocode': {'longitude': Decimal128('0.238196'), 'latitude': Decimal128('52.02372')}}
# {'_id': ObjectId('643057fd130a14a279430108'), 'geocode': {'longitude': Decimal128('0.000298'), 'latitude': Decimal128('51.791102')}}
# {'_id': ObjectId('643057fd130a14a279430109'), 'geocode': {'longitude': Decimal128('0.241706'), 'latitude': Decimal128('52.027466')}}
# {'_id': ObjectId('643057fd130a14a27943010a'), 'geocode': {'longitude': Decimal128('0.2174898'), 'latitude': Decimal128('52.0039971')}}
# {'_id': ObjectId('643057fd130a14a27943010b'), 'geocode': {'longitude': Decimal128('0.238656997680664'), 'latitude': Decimal128('52.0250701904297')}}
# {'_id': ObjectId('643057fd130a14a27943010c'), 'geocode': {'longitude': Decimal128('0.236874999889325'), 'latitude': Decimal128('52.0241300000128')}}
# {'_id': ObjectId('643057fd130a14a27943010d'), 'geocode': {'longitude': Decimal128('0.23667100071907'), 'latitude': Decimal128('52.0252952575684')}}
# {'_id': ObjectId('643057fd130a14a27943010e'), 'geocode': {'longitude': Decimal128('0.090747'), 'latitude': Decimal128('51.884317')}}
# {'_id': ObjectId('643057fd130a14a27943010f'), 'geocode': {'longitude': Decimal128('0.071794'), 'latitude': Decimal128('51.867441')}}
# {'_id': ObjectId('643057fd130a14a279430110'), 'geocode': {'longitude': Decimal128('0.233049'), 'latitude': Decimal128('52.025445')}}
# {'_id': ObjectId('643057fd130a14a279430111'), 'geocode': {'longitude': Decimal128('0.223619'), 'latitude': Decimal128('52.01637')}}
# {'_id': ObjectId('643057fd130a14a279430112'), 'geocode': {'longitude': Decimal128('0.223619'), 'latitude': Decimal128('52.01637')}}
# {'_id': ObjectId('643057fd130a14a279430113'), 'geocode': {'longitude': Decimal128('0.023321'), 'latitude': Decimal128('51.821462')}}
# {'_id': ObjectId('643057fd130a14a279430114'), 'geocode': {'longitude': Decimal128('0.022803'), 'latitude': Decimal128('51.821237')}}
# {'_id': ObjectId('643057fd130a14a279430115'), 'geocode': {'longitude': Decimal128('0.222375'), 'latitude': Decimal128('52.0166285')}}
# {'_id': ObjectId('643057fd130a14a279430116'), 'geocode': {'longitude': Decimal128('0.181523'), 'latitude': Decimal128('51.977888')}}
# {'_id': ObjectId('643057fd130a14a279430117'), 'geocode': {'longitude': Decimal128('0.181523'), 'latitude': Decimal128('51.977888')}}
# {'_id': ObjectId('643057fd130a14a279430118'), 'geocode': {'longitude': Decimal128('0.00092'), 'latitude': Decimal128('51.80253')}}
# {'_id': ObjectId('643057fd130a14a279430119'), 'geocode': {'longitude': Decimal128('0.208299'), 'latitude': Decimal128('52.005652')}}
# {'_id': ObjectId('643057fd130a14a27943011a'), 'geocode': {'longitude': Decimal128('0.208298996090889'), 'latitude': Decimal128('52.0056533813477')}}
# {'_id': ObjectId('643057fd130a14a27943011b'), 'geocode': {'longitude': Decimal128('0.0184494089335203'), 'latitude': Decimal128('51.8202323913574')}}
# {'_id': ObjectId('643057fd130a14a27943011c'), 'geocode': {'longitude': Decimal128('0.220520004630089'), 'latitude': Decimal128('52.0188140869141')}}
# {'_id': ObjectId('643057fd130a14a27943011d'), 'geocode': {'longitude': Decimal128('0.220591'), 'latitude': Decimal128('52.020834')}}
# {'_id': ObjectId('643057fd130a14a27943011e'), 'geocode': {'longitude': Decimal128('0.22059'), 'latitude': Decimal128('52.020834')}}
# {'_id': ObjectId('643057fd130a14a27943011f'), 'geocode': {'longitude': Decimal128('0.204666'), 'latitude': Decimal128('52.005558')}}
# {'_id': ObjectId('643057fd130a14a279430120'), 'geocode': {'longitude': Decimal128('0.19981'), 'latitude': Decimal128('52.00547')}}
# {'_id': ObjectId('643057fd130a14a279430121'), 'geocode': {'longitude': Decimal128('0.215956002473831'), 'latitude': Decimal128('52.0240783691406')}}
# {'_id': ObjectId('643057fd130a14a279430122'), 'geocode': {'longitude': Decimal128('0.135896'), 'latitude': Decimal128('51.947747')}}
# {'_id': ObjectId('643057fd130a14a279430123'), 'geocode': {'longitude': Decimal128('0.085757'), 'latitude': Decimal128('51.90239')}}
# {'_id': ObjectId('643057fd130a14a279430124'), 'geocode': {'longitude': Decimal128('0.158531'), 'latitude': Decimal128('51.973655')}}
# {'_id': ObjectId('643057fd130a14a279430125'), 'geocode': {'longitude': Decimal128('0.153405'), 'latitude': Decimal128('51.970286')}}
# {'_id': ObjectId('643057fd130a14a279430126'), 'geocode': {'longitude': Decimal128('0.110943'), 'latitude': Decimal128('51.929214')}}
# {'_id': ObjectId('643057fd130a14a279430127'), 'geocode': {'longitude': Decimal128('0.14408'), 'latitude': Decimal128('51.962813')}}
# {'_id': ObjectId('643057fd130a14a279430128'), 'geocode': {'longitude': Decimal128('0.14408'), 'latitude': Decimal128('51.962813')}}
# {'_id': ObjectId('643057fd130a14a279430129'), 'geocode': {'longitude': Decimal128('0.144079'), 'latitude': Decimal128('51.962813')}}
# {'_id': ObjectId('643057fd130a14a27943012a'), 'geocode': {'longitude': Decimal128('0.144079'), 'latitude': Decimal128('51.962813')}}
# {'_id': ObjectId('643057fd130a14a27943012b'), 'geocode': {'longitude': Decimal128('0.147576'), 'latitude': Decimal128('51.966832')}}
# {'_id': ObjectId('643057fd130a14a27943012c'), 'geocode': {'longitude': Decimal128('0.090891'), 'latitude': Decimal128('51.912469')}}
# {'_id': ObjectId('643057fd130a14a27943012d'), 'geocode': {'longitude': Decimal128('0.138243'), 'latitude': Decimal128('51.963738')}}
# {'_id': ObjectId('643057fd130a14a27943012e'), 'geocode': {'longitude': Decimal128('0.1109006'), 'latitude': Decimal128('51.9404458')}}
# {'_id': ObjectId('643057fd130a14a27943012f'), 'geocode': {'longitude': Decimal128('0.158823996782303'), 'latitude': Decimal128('51.988224029541')}}
# {'_id': ObjectId('643057fd130a14a279430130'), 'geocode': {'longitude': Decimal128('0.104851'), 'latitude': Decimal128('51.943558')}}
# {'_id': ObjectId('643057fd130a14a279430131'), 'geocode': {'longitude': Decimal128('0.087039'), 'latitude': Decimal128('51.929101')}}
# {'_id': ObjectId('643057fd130a14a279430132'), 'geocode': {'longitude': Decimal128('0.087039'), 'latitude': Decimal128('51.929101')}}
# {'_id': ObjectId('643057fd130a14a279430133'), 'geocode': {'longitude': Decimal128('0.080835'), 'latitude': Decimal128('51.931135')}}
# {'_id': ObjectId('643057fd130a14a279430134'), 'geocode': {'longitude': Decimal128('0.026582'), 'latitude': Decimal128('51.881142')}}
# {'_id': ObjectId('643057fd130a14a279430135'), 'geocode': {'longitude': Decimal128('0.0274349991232157'), 'latitude': Decimal128('51.8827362060547')}}
# {'_id': ObjectId('643057fd130a14a279430136'), 'geocode': {'longitude': Decimal128('0.027352'), 'latitude': Decimal128('51.882764')}}
# {'_id': ObjectId('643057fd130a14a279430137'), 'geocode': {'longitude': Decimal128('0.027352'), 'latitude': Decimal128('51.882765')}}
# {'_id': ObjectId('643057fd130a14a279430138'), 'geocode': {'longitude': Decimal128('0.027352'), 'latitude': Decimal128('51.882765')}}
# {'_id': ObjectId('643057fd130a14a279430139'), 'geocode': {'longitude': Decimal128('0.027352'), 'latitude': Decimal128('51.882765')}}
# {'_id': ObjectId('643057fd130a14a27943013a'), 'geocode': {'longitude': Decimal128('0.0273977'), 'latitude': Decimal128('51.8828612')}}
# {'_id': ObjectId('643057fd130a14a27943013b'), 'geocode': {'longitude': Decimal128('0.0265794'), 'latitude': Decimal128('51.8827584')}}
# {'_id': ObjectId('643057fd130a14a27943013c'), 'geocode': {'longitude': Decimal128('0.02377'), 'latitude': Decimal128('51.884858')}}
# {'_id': ObjectId('643057fd130a14a27943013d'), 'geocode': {'longitude': Decimal128('0.1194518'), 'latitude': Decimal128('51.9826787')}}
# {'_id': ObjectId('643057fd130a14a27943013e'), 'geocode': {'longitude': Decimal128('0.019246'), 'latitude': Decimal128('51.888326')}}
# {'_id': ObjectId('643057fd130a14a27943013f'), 'geocode': {'longitude': Decimal128('0.019246'), 'latitude': Decimal128('51.888326')}}
# {'_id': ObjectId('643057fd130a14a279430140'), 'geocode': {'longitude': Decimal128('0.019246'), 'latitude': Decimal128('51.888326')}}
# {'_id': ObjectId('643057fd130a14a279430141'), 'geocode': {'longitude': Decimal128('0.019246'), 'latitude': Decimal128('51.888327')}}
# {'_id': ObjectId('643057fd130a14a279430142'), 'geocode': {'longitude': Decimal128('0.028537'), 'latitude': Decimal128('51.905548')}}
# {'_id': ObjectId('643057fd130a14a279430143'), 'geocode': {'longitude': Decimal128('0.030806'), 'latitude': Decimal128('51.908153')}}
# {'_id': ObjectId('643057fd130a14a279430144'), 'geocode': {'longitude': Decimal128('0.0132578'), 'latitude': Decimal128('51.8909363')}}
# {'_id': ObjectId('643057fd130a14a279430145'), 'geocode': {'longitude': Decimal128('0.013105'), 'latitude': Decimal128('51.891722')}}
# {'_id': ObjectId('643057fd130a14a279430146'), 'geocode': {'longitude': Decimal128('0.013105'), 'latitude': Decimal128('51.891722')}}
# {'_id': ObjectId('643057fd130a14a279430147'), 'geocode': {'longitude': Decimal128('0.010628'), 'latitude': Decimal128('51.889292')}}
# {'_id': ObjectId('643057fd130a14a279430148'), 'geocode': {'longitude': Decimal128('0.01392'), 'latitude': Decimal128('51.893048')}}
# {'_id': ObjectId('643057fd130a14a279430149'), 'geocode': {'longitude': Decimal128('0.030443'), 'latitude': Decimal128('51.910408')}}
# {'_id': ObjectId('643057fd130a14a27943014a'), 'geocode': {'longitude': Decimal128('0.019504'), 'latitude': Decimal128('51.899922')}}
# {'_id': ObjectId('643057fd130a14a27943014b'), 'geocode': {'longitude': Decimal128('0.011026793682684'), 'latitude': Decimal128('51.8932421230395')}}
# {'_id': ObjectId('643057fd130a14a27943014c'), 'geocode': {'longitude': Decimal128('0.0948920026421547'), 'latitude': Decimal128('51.9761962890625')}}
# {'_id': ObjectId('643057fd130a14a27943014d'), 'geocode': {'longitude': Decimal128('0.024199'), 'latitude': Decimal128('51.908653')}}
# {'_id': ObjectId('643057fd130a14a27943014e'), 'geocode': {'longitude': Decimal128('0.024199'), 'latitude': Decimal128('51.908653')}}
# {'_id': ObjectId('643057fd130a14a27943014f'), 'geocode': {'longitude': Decimal128('0.0104270000010729'), 'latitude': Decimal128('51.9010925292969')}}
# {'_id': ObjectId('643057fd130a14a279430150'), 'geocode': {'longitude': Decimal128('0.012967'), 'latitude': Decimal128('51.904889')}}
# {'_id': ObjectId('643057fd130a14a279430151'), 'geocode': {'longitude': Decimal128('0.012967'), 'latitude': Decimal128('51.904889')}}
# {'_id': ObjectId('643057fd130a14a279430152'), 'geocode': {'longitude': Decimal128('0.1092515'), 'latitude': Decimal128('51.9994109')}}
# {'_id': ObjectId('643057fd130a14a279430153'), 'geocode': {'longitude': Decimal128('0.091986'), 'latitude': Decimal128('51.989774')}}
# {'_id': ObjectId('643057fd130a14a279430154'), 'geocode': {'longitude': Decimal128('0.091986'), 'latitude': Decimal128('51.989774')}}
# {'_id': ObjectId('643057fd130a14a279430155'), 'geocode': {'longitude': Decimal128('0.05443'), 'latitude': Decimal128('51.960014')}}
# {'_id': ObjectId('643057fd130a14a279430156'), 'geocode': {'longitude': Decimal128('0.05443'), 'latitude': Decimal128('51.960014')}}
# {'_id': ObjectId('643057fd130a14a279430157'), 'geocode': {'longitude': Decimal128('0.05443'), 'latitude': Decimal128('51.960014')}}
# {'_id': ObjectId('643057fd130a14a279430158'), 'geocode': {'longitude': Decimal128('0.040668'), 'latitude': Decimal128('51.951216')}}
# {'_id': ObjectId('643057fd130a14a279430159'), 'geocode': {'longitude': Decimal128('0.042066'), 'latitude': Decimal128('51.952838')}}
# {'_id': ObjectId('643057fd130a14a27943015a'), 'geocode': {'longitude': Decimal128('0.056005'), 'latitude': Decimal128('51.977584')}}
# {'_id': ObjectId('643057fd130a14a27943015b'), 'geocode': {'longitude': Decimal128('0.021426'), 'latitude': Decimal128('51.946917')}}
# {'_id': ObjectId('643057fd130a14a27943015c'), 'geocode': {'longitude': Decimal128('0.020803'), 'latitude': Decimal128('51.94763')}}
# {'_id': ObjectId('643057fd130a14a27943015d'), 'geocode': {'longitude': Decimal128('0.021544'), 'latitude': Decimal128('51.949541')}}
# {'_id': ObjectId('643057fd130a14a27943015e'), 'geocode': {'longitude': Decimal128('0.021544'), 'latitude': Decimal128('51.949541')}}
# {'_id': ObjectId('643057fd130a14a27943015f'), 'geocode': {'longitude': Decimal128('0.021544000133872'), 'latitude': Decimal128('51.9495429992676')}}
# {'_id': ObjectId('643057fd130a14a279430160'), 'geocode': {'longitude': Decimal128('0.021544000133872'), 'latitude': Decimal128('51.9495429992676')}}
# {'_id': ObjectId('643057fd130a14a279430161'), 'geocode': {'longitude': Decimal128('0.046496'), 'latitude': Decimal128('51.978523')}}
# {'_id': ObjectId('643057fd130a14a279430162'), 'geocode': {'longitude': Decimal128('0.025416'), 'latitude': Decimal128('51.957963')}}
# {'_id': ObjectId('643057fd130a14a279430163'), 'geocode': {'longitude': Decimal128('0.025416'), 'latitude': Decimal128('51.957963')}}
# {'_id': ObjectId('643057fd130a14a279430164'), 'geocode': {'longitude': Decimal128('0.0432'), 'latitude': Decimal128('51.97618')}}
# {'_id': ObjectId('643057fd130a14a279430165'), 'geocode': {'longitude': Decimal128('0.054737'), 'latitude': Decimal128('51.991247')}}
# {'_id': ObjectId('643057fd130a14a279430166'), 'geocode': {'longitude': Decimal128('0.011433'), 'latitude': Decimal128('51.949606')}}
# {'_id': ObjectId('643057fd130a14a279430167'), 'geocode': {'longitude': Decimal128('0.054535'), 'latitude': Decimal128('51.994776')}}
# {'_id': ObjectId('643057fd130a14a279430168'), 'geocode': {'longitude': Decimal128('0.001967'), 'latitude': Decimal128('51.947799')}}
# {'_id': ObjectId('643057fd130a14a279430169'), 'geocode': {'longitude': Decimal128('0.0800794'), 'latitude': Decimal128('52.025819')}}
# {'_id': ObjectId('643057fd130a14a27943016a'), 'geocode': {'longitude': Decimal128('0.037832'), 'latitude': Decimal128('51.994886')}}
# {'_id': ObjectId('643057fd130a14a27943016b'), 'geocode': {'longitude': Decimal128('0.037832'), 'latitude': Decimal128('51.994886')}}
# {'_id': ObjectId('643057fd130a14a27943016c'), 'geocode': {'longitude': Decimal128('0.030555'), 'latitude': Decimal128('51.992134')}}
# {'_id': ObjectId('643057fd130a14a27943016d'), 'geocode': {'longitude': Decimal128('0.014154'), 'latitude': Decimal128('51.995383')}}
# {'_id': ObjectId('643057fd130a14a27943016e'), 'geocode': {'longitude': Decimal128('0.0108949'), 'latitude': Decimal128('51.9945135')}}
# {'_id': ObjectId('643057fd130a14a27943016f'), 'geocode': {'longitude': Decimal128('0.0153124'), 'latitude': Decimal128('52.0004358')}}
# {'_id': ObjectId('643057fd130a14a279430170'), 'geocode': {'longitude': Decimal128('0.042365'), 'latitude': Decimal128('52.026954')}}
# {'_id': ObjectId('643057fd130a14a279430171'), 'geocode': {'longitude': Decimal128('0.0418439991772175'), 'latitude': Decimal128('52.0270614624023')}}
# {'_id': ObjectId('643057fd130a14a279430172'), 'geocode': {'longitude': Decimal128('0.041802'), 'latitude': Decimal128('52.027063')}}
# {'_id': ObjectId('643057fd130a14a279430173'), 'geocode': {'longitude': Decimal128('0.0418020002543926'), 'latitude': Decimal128('52.0270652770996')}}
# {'_id': ObjectId('643057fd130a14a279430174'), 'geocode': {'longitude': Decimal128('0.0147203'), 'latitude': Decimal128('52.000754')}}
# {'_id': ObjectId('643057fd130a14a279430175'), 'geocode': {'longitude': Decimal128('0.0386321'), 'latitude': Decimal128('52.0263097')}}
# {'_id': ObjectId('643057fd130a14a279430176'), 'geocode': {'longitude': Decimal128('0.0159242'), 'latitude': Decimal128('52.0044032')}}
# {'_id': ObjectId('643057fd130a14a279430177'), 'geocode': {'longitude': Decimal128('0.032513'), 'latitude': Decimal128('52.024742')}}
# {'_id': ObjectId('643058399420424c529ed646'), 'geocode': {'longitude': Decimal128('0.08384000'), 'latitude': Decimal128('51.49014200')}}
